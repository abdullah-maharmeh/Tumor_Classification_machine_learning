# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display
from google.colab.patches import cv2_imshow

# %%
# read and write images
# note that colab has it's own function to show the image cv2_imshow
import cv2
image = cv2.imread('/content/drive/MyDrive/Tumor classification/images/images/6689.png')
# print('Shape',image.shape)
# print('size',image.size)
# print('type',image.dtype)

kernel = np.ones((5,5))


cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=726x573>

# %%
dim = (256,256)

image = cv2.resize(image,dim,interpolation=cv2.INTER_AREA)


print('resiseid shape',image.shape)
print('resized size', image.size)
print('resized type',image.dtype)
cv2_imshow(image)
# Out:
# resiseid shape (256, 256, 3)
# resized size 196608
# resized type uint8
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
median =  cv2.medianBlur(gray,5)
cv2_imshow(median)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
# global thresholding
ret1,th1 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv2.threshold(gray ,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
ret3,th3 = cv2.threshold(median,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# plot all the images and their histograms
images = [image, 0, th1,
 image, 0, th2,
 median, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
 'Original Noisy Image','Histogram',"Otsu's Thresholding",
 'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
plt.figure(figsize=(15,15))
for i in range(3):
 plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
 plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
 plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
 plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
 plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
 plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
edges = cv2.Canny(th3,50,150)
plt.subplot(121),plt.imshow(median,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# sure background area
sure_bg = cv2.dilate(edges, kernel, iterations=3)
cv2_imshow(sure_bg)


# Distance transform
dist = cv2.distanceTransform(edges, cv2.DIST_L2, 5)
cv2_imshow(dist)


#foreground area
ret, sure_fg = cv2.threshold(dist, 0.5 * dist.max(), 255, cv2.THRESH_BINARY)
sure_fg = sure_fg.astype(np.uint8)
cv2_imshow(sure_fg)
axes[1, 0].set_title('Sure Foreground')

# unknown area
unknown = cv2.subtract(sure_bg, sure_fg)
cv2_imshow(unknown)

plt.show()
# Out:
# <PIL.Image.Image image mode=L size=256x256>
# <PIL.Image.Image image mode=L size=256x256>
# <PIL.Image.Image image mode=L size=256x256>
# <PIL.Image.Image image mode=L size=256x256>

# %%
ret, markers = cv2.connectedComponents(sure_fg)

# Add one to all labels so that background is not 0, but 1
markers += 1
# mark the region of unknown with zero
markers[unknown == 255] = 0

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(markers, cmap="tab20b")
ax.axis('off')
plt.show()

# %%
markers = cv2.watershed(image, markers)

fig, ax = plt.subplots(figsize=(5, 5))
ax.imshow(markers, cmap="tab20b")
ax.axis('off')
plt.show()


labels = np.unique(markers)

coins = []
for label in labels[2:]:

# Create a binary image in which only the area of the label is in the foreground
#and the rest of the image is in the background
    target = np.where(markers == label, 255, 0).astype(np.uint8)

  # Perform contour extraction on the created binary image
    contours, hierarchy = cv2.findContours(
        target, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
    )
    coins.append(contours[0])

# Draw the outline
img = cv2.drawContours(image, coins, -1, color=(0, 23, 223), thickness=2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
def image_preprocess(image):
  # resized image to 250 * 250
  resized = cv2.resize(image,(256,256),interpolation=cv2.INTER_AREA)
  # cv2_imshow(resized)
  # checking if the operation act good
  # print(resized.shape)

  #change image to gray
  gray = cv2.cvtColor(resized,cv2.COLOR_BGR2GRAY)
  # apply median filter to the image
  gray = cv2.medianBlur(gray,5)
  # apply OTSU thresholding after applying median and canny
  ret , thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
  # apply edge canny method on the image
  canny = cv2.Canny(thresh,100,200)
  # apply watershed algorithm
  # background area
  kernel = np.ones((5,5))
  sure_bg = cv2.dilate(canny,kernel=np.ones((5,5)),iterations= 3)
  # for check the output result
  # cv2_imshow(sure_bg)
  #Distance transform
  dist = cv2.distanceTransform(canny,cv2.DIST_L2,5)
  # foreground area
  ret , sure_fg = cv2.threshold(dist,0.5 * dist.max(),255,cv2.THRESH_BINARY)
  sure_fg = sure_fg.astype(np.uint8)

  # unknown area
  unknown = cv2.subtract(sure_bg, sure_fg)

  # for checking the unkown area
  # cv2_imshow(unknown)
  # create markers
  ret, markers = cv2.connectedComponents(sure_fg)

  # Add one to all labels so that background is not 0, but 1
  markers += 1
  # mark the region of unknown with zero
  markers[unknown == 255] = 0

  # apply watershed to the image

  markers = cv2.watershed(resized , markers)

  labels = np.unique(markers)

  coins = []
  for label in labels[2:]:

      # Create a binary image in which only the area of the label is in the foreground
      #and the rest of the image is in the background
      target = np.where(markers == label, 255, 0).astype(np.uint8)

    # Perform contour extraction on the created binary image
      contours, hierarchy = cv2.findContours(
          target, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
      )
      coins.append(contours[0])

  # Draw the outline
  img = cv2.drawContours(resized, coins, -1, color=(0, 23, 223), thickness=2)
  return img , target

# %%
image_folder_path = '/content/drive/MyDrive/Tumor classification/images/images/'

# List all image files in the folder
import os

image_files = os.listdir(image_folder_path)
image_files = [file for file in image_files if file.endswith('.png')]  # Adjust the file extension

# Print the list of image file names
print(image_files)
# Out:
# ['1138.png', '1097.png', '1068.png', '1091.png', '1154.png', '1127.png', '1006.png', '1159.png', '1105.png', '1070.png', '1156.png', '1183.png', '1062.png', '1046.png', '1191.png', '1202.png', '1073.png', '1028.png', '1066.png', '1316.png', '1681.png', '1589.png', '1503.png', '1300.png', '1579.png', '1458.png', '1640.png', '1341.png', '1501.png', '1383.png', '1815.png', '1490.png', '1333.png', '1235.png', '1844.png', '1750.png', '1646.png', '1255.png', '1340.png', '1676.png', '1343.png', '1366.png', '1704.png', '1608.png', '1230.png', '1453.png', '1577.png', '1240.png', '1766.png', '1379.png', '1435.png', '1378.png', '1870.png', '1715.png', '1610.png', '1735.png', '1802.png', '1450.png', '1362.png', '1480.png', '1277.png', '1293.png', '1253.png', '1403.png', '1367.png', '1285.png', '1234.png', '1515.png', '1687.png', '1653.png', '1218.png', '1331.png', '1310.png', '1568.png', '1777.png', '1532.png', '2332.png', '2471.png', '1983.png', '2076.png', '2458.png', '2143.png', '2388.png', '
# ...
